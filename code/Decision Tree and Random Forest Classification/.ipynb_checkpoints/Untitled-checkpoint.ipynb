# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import random
import json
# %matplotlib inline

# %%
def start(df):
    df.rename(
        columns={
            "Operator": "op",
            "In Out Travelling": "inOut",
            "Network Type": "nwrk",
            "Latitude": "lat",
            "Longitude": "long",
            "Call Drop Category": "cdc",
            "Rating": "rt",
            "State Name": "stn"
        },
        inplace=True
        )
    df=df.dropna()
    column_titles = ['inOut','nwrk','rt','cdc','lat','long','stn','op']
    df=df.reindex(columns=column_titles)
    return df

# %%
# month=["April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019"]
# month=["JUNE 2018","july 2018"]
month=["April 2018"]

# %%
sumAccuracy=0
for i in range(len(month)):
    print("month: ",month[i],"...")
    df = pd.read_csv('../data/'+month[i]+'/Training_Data_Set.csv')
    # # df2 = pd.read_csv('testing1.csv')
    df2=pd.read_csv('../data/'+month[i]+'/Testing_Data_Set.csv')
    df=start(df)
    df2=start(df2)
    print(df.head())
    print(df2.head())
# Out:
# month:  April 2018 ...
#     inOut nwrk  rt  cdc        lat       long            stn      op
# 0  Indoor   4G   4    2  28.528862  77.399903  Uttar Pradesh    RJio
# 1  Indoor   2G   4    2  11.271128  76.238910         Kerala    BSNL
# 2  Indoor   4G   4    2  26.021410  89.992652          Assam    RJio
# 3  Indoor   3G   1    2  28.631353  77.205540            NCT  Airtel
# 4  Indoor   3G   4    2  28.390937  76.958238        Haryana  Airtel
#      inOut nwrk  rt  cdc        lat       long            stn      op
# 0   Indoor   3G   5    2  28.422966  76.912324        Haryana  Airtel
# 1   Indoor   4G   2    2   9.426251  77.802405     Tamil Nadu    RJio
# 2  Outdoor   4G   5    2  26.781342  82.150961  Uttar Pradesh  Airtel
# 3   Indoor   4G   1    1  13.010252  77.703402      Karnataka  Airtel
# 4   Indoor   4G   5    2  12.750605  77.845415     Tamil Nadu    BSNL

# %%
df=pd.read_csv("./reports/report_May 2018.csv", nrows=10)

# %%
df
# Out:
#    Max Depth  Accuracy
# 0         10  0.700245
# 1         15  0.754809
# 2         20  0.835257
# 3         25  0.892620
# 4         30  0.901014
# 5         35  0.899265
# 6         40  0.899265
# 7         45  0.899265
# 8         50  0.899265
# 9         55  0.899265

# %%
month:  April 2018 ...
0.68210197710718
month:  April 2018 ...
0.7478321193201526
month:  April 2018 ...
0.836975372875477
month:  April 2018 ...
0.8909122441900797
month:  April 2018 ...
0.9028789455428373
month:  April 2018 ...
0.9195282691640652
month:  April 2018 ...
0.9231703087062089
month:  April 2018 ...
0.9231703087062089
month:  April 2018 ...
0.9231703087062089
month:  April 2018 ...
0.9231703087062089

# %%
# for i in range(10):
df["Accuracy"][9]=0.9231703087062089
# Out:
# C:\Users\Anuj Kharbanda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.columns=["Max Depth","Accuracy"]

# %%
df.to_csv('./reports/report_April 2018.csv',index=False,header=True)

# %%
df
# Out:
#    Max Depth  Accuracy
# 0         11  0.682102
# 1         15  0.747832
# 2         20  0.836975
# 3         25  0.890912
# 4         30  0.902879
# 5         35  0.919528
# 6         40  0.923170
# 7         45  0.923170
# 8         50  0.923170
# 9         55  0.923170

# %%
df
# Out:
#    Max Depth  Accuracy
# 0         11  0.682102
# 1         15  0.747832
# 2         20  0.836975
# 3         25  0.890912
# 4         30  0.902879
# 5         35  0.919528
# 6         40  0.923170
# 7         45  0.923170
# 8         50  0.923170
# 9         55  0.923170

# %%
df2
# Out:
#            inOut nwrk  rt  cdc        lat       long             stn        op
# 0         Indoor   3G   5    2  28.422966  76.912324         Haryana    Airtel
# 1         Indoor   4G   2    2   9.426251  77.802405      Tamil Nadu      RJio
# 2        Outdoor   4G   5    2  26.781342  82.150961   Uttar Pradesh    Airtel
# 3         Indoor   4G   1    1  13.010252  77.703402       Karnataka    Airtel
# 4         Indoor   4G   5    2  12.750605  77.845415      Tamil Nadu      BSNL
# 5         Indoor   4G   4    2  12.683241  77.878702      Tamil Nadu      BSNL
# 6        Outdoor   4G   5    2  19.206964  73.002762     Maharashtra  Vodafone
# 7         Indoor   4G   1    1  22.714307  75.873752  Madhya Pradesh      Idea
# 8        Outdoor   4G   5    2  11.017377  76.920361      Tamil Nadu    Airtel
# 9         Indoor   4G   5    2  22.795423  86.231791       Jharkhand      RJio
# 10        Indoor   4G   3    2  10.815756  79.840731      Tamil Nadu      RJio
# ...

# %%
a=[[1,2],[3,4],[5,6]]
DF = pd.DataFrame(a, columns = ["No. of trees", "Accuracy"])

# %%
df = pd.DataFrame()

# %%
for i in DF:
    df[i]=DF[i]

# %%
df
# Out:
#    No. of trees  Accuracy
# 0             1         2
# 1             3         4
# 2             5         6

# %%
random.sample(population=[1,2,3,4,5], k=2)
# Out:
# [1, 2]

# %%
if 1<2:
    print("yes")

#qwhjkdh
else:
    print("no")
# Out:
# yes
