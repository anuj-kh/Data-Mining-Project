# %% [markdown]
# # Code to run Chi-square test

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
month=["../../data/April 2018","../../data/May 2018","../../data/June 2018","../../data/July 2018","../../data/August 2018","../../data/September 2018","../../data/October 2018","../../data/November 2018","../../data/December 2018","../../data/January 2019","../../data/February 2019","../../data/March 2019"]
month2=["April_2018","May_2018","June_2018","July_2018","August_2018","September_2018","October_2018","November_2018","December_2018","January_2019","February_2019","March_2019"]
month3=["April 2018","May 2018","June 2018","July 2018","August 2018","September 2018","October 2018","November 2018","December 2018","January 2019","February 2019","March 2019"]

# %% [markdown]
# # Creating a blank dataframe which will append the data of all the months

# %%
df2= pd.DataFrame(columns=['Operator','In Out Travelling','Network Type','Rating','Call Drop Category','Latitude','Longitude','State Name'])

# %%
print('H0 = Rating and Call Drop Category are independent')
# Out:
# H0 = Rating and Call Drop Category are independent

# %% [markdown]
# # Running a loop to find the chi-square value of data of each month individually

# %%
for i in range(len(month)): 
    df=pd.read_csv(month[i]+"/Cleaned_and_Encoded_Data_Set_"+month2[i]+".csv")
    df2=df2.append(df, ignore_index = True) 
    #df=pd.read_csv("Encoded_Training_Set_April_2018.csv")
    #df2=df2.append(df, ignore_index = True)
    print("\nFor","\033[1m",month3[i],"\033[0m",":\n")
    val = pd.crosstab(df['Rating'],df['Call Drop Category'],margins = False)
    print(val)

    stat, p, dof, expected = chi2_contingency(val)
    print('\ndof=%d' % dof)
    print("Expected Value Matrix:")
    print(expected)

    prob = 0.95
    critical = chi2.ppf(prob, dof)
    print('\nprobability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
    if abs(stat) >= critical:
        print('Dependent (reject H0)')
    else:
        print('Independent (fail to reject H0)')
    
    alpha = 1.0 - prob
    print('significance=%.3f, p=%.3f' % (alpha, p))
    if p <= alpha:
        print('Dependent (reject H0)')
    else:
        print('Independent (fail to reject H0)') 
    print()
# Out:
# For  April 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2438  3749    952
# 2                    479  1394   1426
# 3                    209  1537   2840
# 4                      0     0  12965
# 5                      0     0  10750
#
# dof=8
# Expected Value Matrix:
# [[ 576.07356927 1231.02093498 5331.90549575]
#  [ 266.20909161  568.86651695 2463.92439144]
#  [ 370.06210795  790.79170861 3425.14618343]
#  [1046.19608147 2235.63334108 9683.17057745]
#  [ 867.45914969 1853.68749839 8028.85335192]]
#
# probability=0.950, critical=15.507, stat=25482.061
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  May 2018  :
#
# Call Drop Category     0     1     2
# Rating
# 1                   1054  2454     0
# 2                    194  1533     0
# 3                     64   794  1214
# 4                      0     0  5412
# 5                      0     0  6339
#
# dof=8
# Expected Value Matrix:
# [[ 241.49942281  880.03714975 2386.46342743]
#  [ 118.89096442  433.24519887 1174.86383671]
#  [ 142.64162032  519.79389233 1409.56448735]
#  [ 372.57550635 1357.68559135 3681.7389023 ]
#  [ 436.3924861  1590.2381677  4312.36934621]]
#
# probability=0.950, critical=15.507, stat=17686.659
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  June 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2525  5263      0
# 2                    326  3845      0
# 3                    133  1224   2760
# 4                      0     0  10497
# 5                      0     0  14639
#
# dof=8
# Expected Value Matrix:
# [[ 563.89867029 1952.48024847 5271.62108124]
#  [ 302.00582355 1045.68504319 2823.30913326]
#  [ 298.0958944  1032.14704455 2786.75706105]
#  [ 760.04678249 2631.63651364 7105.31670387]
#  [1059.95282927 3670.05115015 9908.99602058]]
#
# probability=0.950, critical=15.507, stat=40149.897
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  July 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2578  4832      0
# 2                    296  3227      0
# 3                    241  1305   3203
# 4                      0     0   8214
# 5                      0     0  15085
#
# dof=8
# Expected Value Matrix:
# [[  592.13847772  1780.02719273  5037.83432955]
#  [  281.52548678   846.29363023  2395.18088299]
#  [  379.49603653  1140.80285267  3228.7011108 ]
#  [  656.38670121  1973.16374644  5584.44955235]
#  [ 1205.45329776  3623.71257792 10255.83412432]]
#
# probability=0.950, critical=15.507, stat=37068.915
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  August 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2571  4628      0
# 2                    279  3037      0
# 3                    210  1342   3219
# 4                      0     0   8395
# 5                      0     0  13904
#
# dof=8
# Expected Value Matrix:
# [[ 586.10988426 1725.19337502 4887.69674072]
#  [ 269.9736597   794.65776241 2251.36857789]
#  [ 388.43315152 1143.33901823 3239.22783025]
#  [ 683.48277238 2011.80697087 5699.71025675]
#  [1132.00053213 3332.00287349 9439.99659439]]
#
# probability=0.950, critical=15.507, stat=35734.332
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  September 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2717  5685      0
# 2                    400  3572      0
# 3                    312  1795   3192
# 4                      0     0   8695
# 5                      0     0  13765
#
# dof=8
# Expected Value Matrix:
# [[ 717.87451723 2313.77928388 5370.34619889]
#  [ 339.37129046 1093.82662647 2538.80208307]
#  [ 452.75137667 1459.261655   3386.98696833]
#  [ 742.90870356 2394.46689757 5557.62439887]
#  [1176.09411208 3790.66553709 8798.24035083]]
#
# probability=0.950, critical=15.507, stat=36824.882
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  October 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   3061  5803      0
# 2                    482  3688      0
# 3                    378  1158   4280
# 4                      0     0  11548
# 5                      0     0  14862
#
# dof=8
# Expected Value Matrix:
# [[  767.91303579  2085.56641626  6010.52054795]
#  [  361.25872735   981.13853292  2827.60273973]
#  [  503.85629695  1368.41767565  3943.7260274 ]
#  [ 1000.43543968  2717.07140963  7830.49315068]
#  [ 1287.53650022  3496.80596553 10077.65753425]]
#
# probability=0.950, critical=15.507, stat=42450.600
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  November 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2630  4527      0
# 2                    292  3207      0
# 3                    227   919   3993
# 4                      0     0   9914
# 5                      0     0  14807
#
# dof=8
# Expected Value Matrix:
# [[  556.25908283  1528.52011551  5072.22080166]
#  [  271.9506121    747.28124691  2479.76814098]
#  [  399.41531741  1097.5359611   3642.04872149]
#  [  770.53968802  2117.33246125  7026.12785073]
#  [ 1150.83529963  3162.33021522 10493.83448514]]
#
# probability=0.950, critical=15.507, stat=39560.874
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  December 2018  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2699  5509      0
# 2                    328  3895      0
# 3                    254  1325   4901
# 4                      0     0  12697
# 5                      0     0  15642
#
# dof=8
# Expected Value Matrix:
# [[  569.95657143  1863.78057143  5774.26285714]
#  [  293.24154497   958.9114709   2970.84698413]
#  [  449.96571429  1471.40571429  4558.62857143]
#  [  881.66893122  2883.09233862  8932.23873016]
#  [ 1086.1672381   3551.80990476 11004.02285714]]
#
# probability=0.950, critical=15.507, stat=44891.509
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  January 2019  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   3202  5383      0
# 2                    289  3883      0
# 3                    189  1115   5465
# 4                      0     0  13616
# 5                      0     0  18418
#
# dof=8
# Expected Value Matrix:
# [[  612.73855702  1728.48884794  6243.77259503]
#  [  297.76881303   839.98316524  3034.24802172]
#  [  483.12490303  1362.85859193  4923.01650504]
#  [  971.81691234  2741.42156711  9902.76152056]
#  [ 1314.55081458  3708.24782777 13395.20135764]]
#
# probability=0.950, critical=15.507, stat=51266.005
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  February 2019  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   2393  5890      0
# 2                    303  3873      0
# 3                    184  1160   4987
# 4                      0     0  10789
# 5                      0     0  17139
#
# dof=8
# Expected Value Matrix:
# [[  510.61774905  1936.62419196  5835.75805899]
#  [  257.4356779    976.37844086  2942.18588124]
#  [  390.28383064  1480.23273685  4460.48343251]
#  [  665.10381438  2522.54477931  7601.35140631]
#  [ 1056.55892804  4007.21985102 12075.22122094]]
#
# probability=0.950, critical=15.507, stat=44341.249
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
#
#
# For  March 2019  :
#
# Call Drop Category     0     1      2
# Rating
# 1                   1323  3836      0
# 2                    224  3008      0
# 3                    124   580   3193
# 4                      0     0   6470
# 5                      0     0  10125
#
# dof=8
# Expected Value Matrix:
# [[ 298.4693072  1326.05394177 3534.47675103]
#  [ 186.98445452  830.74362082 2214.27192466]
#  [ 225.45743171 1001.67323339 2669.8693349 ]
#  [ 374.31603365 1663.0294637  4432.65450265]
#  [ 585.77277291 2602.49974033 6936.72748676]]
#
# probability=0.950, critical=15.507, stat=27683.070
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)

# %% [markdown]
# # Now finally finding the chi-square value of the complete data appended together

# %%
print("For\033[1m whole 12 months data\033[0m:\n")
val2 = pd.crosstab(df2['Rating'], df2['Call Drop Category'],margins=False)
print(val2)
stat, p, dof, expected = chi2_contingency(val2)
print('\ndof=%d' % dof)
print("Expected Value Matrix:")
print(expected)

prob = 0.95
critical = chi2.ppf(prob, dof)
print('\nprobability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')

alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# For whole 12 months data:
#
# Call Drop Category      0      1       2
# Rating
# 1                   29191  57559     952
# 2                    3892  38162    1426
# 3                    2525  14254   43247
# 4                       0      0  119212
# 5                       0      0  165475
#
# dof=8
# Expected Value Matrix:
# [[  6562.14672564  20267.13340128  60872.71987308]
#  [  3253.3139453   10047.83197974  30178.85407495]
#  [  4491.33907269  13871.46187709  41663.19905021]
#  [  8919.82663403  27548.80740499  82743.36596098]
#  [ 12381.37362233  38239.76533689 114853.86104078]]
#
# probability=0.950, critical=15.507, stat=438224.114
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)
